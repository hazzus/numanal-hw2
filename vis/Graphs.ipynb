# %%
import matplotlib.pyplot as plt

# %%
with open('../task2/iterations_dominated') as f: jacobi_dominated = list(map(float, f.read().split()))
len(jacobi_dominated)
# Out:
# 31

# %%
with open('../task3/iterations_dominated') as f: seidel_dominated = list(map(float, f.read().split()))
len(seidel_dominated)
# Out:
# 13

# %%
with open('../task4/iterations_dominated') as f: seidel2_dominated = list(map(float, f.read().split()))
len(seidel2_dominated)
# Out:
# 38

# %%
with open('../task5/iterations_dominated') as f: descent_dominated = list(map(float, f.read().split()))
len(descent_dominated)
# Out:
# 11

# %%
minlen = min(list(map(len, [jacobi_dominated, seidel_dominated, seidel2_dominated, descent_dominated])))
iters = list(range(maxlen))

# %%
plt.plot(iters[1:minlen], jacobi_dominated[1:minlen], label="Jacobi")
plt.plot(iters[1:minlen], seidel_dominated[1:minlen], label="Seidel")
plt.plot(iters[1:minlen], seidel2_dominated[1:minlen], label="Seidel (relaxed)")
plt.plot(iters[1:minlen], descent_dominated[1:minlen], label="Descent")
plt.legend()
plt.xlabel('Количество итераций')
plt.ylabel('|Ax - b|')
plt.savefig('./graphs/dominated.png', dpi=100)
plt.show()

# %%
with open('../task3/iterations_random') as f: seidel_random = list(map(float, f.read().split()))
len(seidel_random)
# Out:
# 414

# %%
with open('../task5/iterations_random') as f: descent_random = list(map(float, f.read().split()))
len(descent_random)
# Out:
# 11

# %%
plt.plot(iters[1:len(descent_random)], seidel_random[1:len(descent_random)], label="Seidel")
plt.plot(iters[1:len(descent_random)], descent_random[1:], label="Descent")
plt.legend()
plt.savefig('./graphs/random.png', dpi=100)
plt.show()

# %%
with open('../task3/iterations_hilbert') as f: seidel_hilbert = list(map(float, f.read().split()))
len(seidel_hilbert)
# Out:
# 307

# %%
with open('../task5/iterations_hilbert') as f: descent_hilbert = list(map(float, f.read().split()))
len(descent_hilbert)
# Out:
# 11

# %%
plt.plot(iters[1:len(descent_hilbert)], seidel_hilbert[1:len(descent_hilbert)], label="Seidel")
plt.plot(iters[1:len(descent_hilbert)], descent_hilbert[1:len(descent_hilbert)], label="Descent")
plt.legend()
plt.savefig('./graphs/hilbert.png', dpi=100)
plt.show()
